# %%
import pandas as pd

# %%
SHEET_ID = '1ZST9mROwpwAwRC95riuN7-FNOMfC-3UEmifGVrPCXE8'
SHEET_NAME = 'Coniugazione'

url = f'https://docs.google.com/spreadsheets/d/{SHEET_ID}/gviz/tq?tqx=out:csv&sheet={SHEET_NAME}'
df = pd.read_csv(url)

# %%
df
# Out:
#      Verbe  Regulier  Persona      Io     Tu    Lei       Noi      Voi  \
# 0   essere     False        2    sono    sei      è     siamo    siete
# 1    avere     False        2      ho    hai     ha   abbiamo    avete
# 2   volere     False        2  voglio   vuoi  vuole  vogliamo   volete
# 3  parlare      True        1   parlo  parli  parle  parliamo  parlate
# 4   potere     False        2   posso   puoi    può  possiamo   potete
#
#        Loro
# 0      sono
# 1     hanno
# 2  vogliono
# 3   parlono
# 4   possono

# %%
SHEET_ID = '2PACX-1vR7I66tFlU4vJ2Nnl0_sRI9xTCW-88Aq7Rjp7xoqnjw8P11ITVMp9HKmlAop21e2kM0yDtm5JBEDtby'

df = pd.read_excel(f'https://docs.google.com/spreadsheets/d/e/{SHEET_ID}/pub?output=xlsx', sheet_name='Indicativo')

# %%
df
# Out:
#      Verbe  Regulier  Persona      Io     Tu    Lei       Noi      Voi  \
# 0   essere     False      2.0    sono    sei      è     siamo    siete
# 1    avere     False      2.0      ho    hai     ha   abbiamo    avete
# 2   volere     False      2.0  voglio   vuoi  vuole  vogliamo   volete
# 3  parlare      True      1.0   parlo  parli  parle  parliamo  parlate
# 4   potere     False      2.0   posso   puoi    può  possiamo   potete
#
#        Loro
# 0      sono
# 1     hanno
# 2  vogliono
# 3   parlono
# 4   possono
